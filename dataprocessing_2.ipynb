# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.0.2 is available.
# You should consider upgrading via the 'c:\users\pc\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
info=pd.read_csv('dataset_2.csv')
info
# Out:
#            city        date   rate
# 0     Ahmedabad  2019-04-22  70.32
# 1     Ahmedabad  2019-04-22  70.32
# 2     Ahmedabad  2019-04-22  70.32
# 3     Ahmedabad  2019-04-22  70.32
# 4     Ahmedabad  2019-04-22  70.32
# ...         ...         ...    ...
# 1019  Ahmedabad  2022-01-23  95.11
# 1020  Ahmedabad  2022-01-24  95.11
# 1021  Ahmedabad  2022-01-25  95.11
# 1022  Ahmedabad  2022-01-26  95.11
# 1023  Ahmedabad  2022-01-27  95.11
#
# [1024 rows x 3 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

info.head()
# Out:
#         city        date   rate
# 0  Ahmedabad  2019-04-22  70.32
# 1  Ahmedabad  2019-04-22  70.32
# 2  Ahmedabad  2019-04-22  70.32
# 3  Ahmedabad  2019-04-22  70.32
# 4  Ahmedabad  2019-04-22  70.32

# %%
info.dtypes
# Out:
# city     object
# date     object
# rate    float64
# dtype: object

# %%
info.isnull().sum()
# Out:
# city    0
# date    0
# rate    0
# dtype: int64

# %%
info.columns.tolist()
# Out:
# ['city', 'date', 'rate']

# %%
info.dtypes
# Out:
# city     object
# date     object
# rate    float64
# dtype: object

# %%
#changing datetime  to pd.datetime
info['date']=pd.to_datetime(info['date'])

# %%
info.describe()
# Out:
#               rate
# count  1024.000000
# mean     79.445804
# std      11.439753
# min      67.150000
# 25%      70.390000
# 50%      70.805000
# 75%      89.000000
# max     106.630000

# %%
#looking for unique values in each column
for i in list(info.columns):
    print(i)
    print(f'Unique{i}:{info.nunique()}')
# Out:
# city
# Uniquecity:city      1
# date    642
# rate    323
# dtype: int64
# date
# Uniquedate:city      1
# date    642
# rate    323
# dtype: int64
# rate
# Uniquerate:city      1
# date    642
# rate    323
# dtype: int64

# %%
info.isnull().sum()
# Out:
# city    0
# date    0
# rate    0
# dtype: int64

# %%
#Maximum petrol prices
info.max()
# Out:
# city              Ahmedabad
# date    2022-01-27 00:00:00
# rate                 106.63
# dtype: object

# %%
info.min()
# Out:
# city              Ahmedabad
# date    2019-04-22 00:00:00
# rate                  67.15
# dtype: object

# %%
#Explanationary analysis & visualization
'''1.Date
2.City
3.Rate
'''
#change the dates to year day week

info['Year']   = info['date'].dt.year
info['Day']    =  info['date'].dt.day
info['Week']   = info['date'].dt.week
info['Month']  =  info['date'].dt.month_name()
info['dayname'] = info['date'].dt.day_name()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/3575135697.py:10: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   info['Week']   = info['date'].dt.week

# %%
info
# Out:
#            city       date   rate  Year  Day  Week    Month    dayname
# 0     Ahmedabad 2019-04-22  70.32  2019   22    17    April     Monday
# 1     Ahmedabad 2019-04-22  70.32  2019   22    17    April     Monday
# 2     Ahmedabad 2019-04-22  70.32  2019   22    17    April     Monday
# 3     Ahmedabad 2019-04-22  70.32  2019   22    17    April     Monday
# 4     Ahmedabad 2019-04-22  70.32  2019   22    17    April     Monday
# ...         ...        ...    ...   ...  ...   ...      ...        ...
# 1019  Ahmedabad 2022-01-23  95.11  2022   23     3  January     Sunday
# 1020  Ahmedabad 2022-01-24  95.11  2022   24     4  January     Monday
# 1021  Ahmedabad 2022-01-25  95.11  2022   25     4  January    Tuesday
# 1022  Ahmedabad 2022-01-26  95.11  2022   26     4  January  Wednesday
# 1023  Ahmedabad 2022-01-27  95.11  2022   27     4  January   Thursday
#
# [1024 rows x 8 columns]

# %%
info['date'].unique()
# Out:
# array(['2019-04-22T00:00:00.000000000', '2019-04-25T00:00:00.000000000',
#        '2019-04-27T00:00:00.000000000', '2019-04-30T00:00:00.000000000',
#        '2019-05-02T00:00:00.000000000', '2019-05-04T00:00:00.000000000',
#        '2019-05-05T00:00:00.000000000', '2019-05-06T00:00:00.000000000',
#        '2019-05-09T00:00:00.000000000', '2019-05-10T00:00:00.000000000',
#        '2019-05-11T00:00:00.000000000', '2019-05-12T00:00:00.000000000',
#        '2019-05-13T00:00:00.000000000', '2019-05-14T00:00:00.000000000',
#        '2019-05-17T00:00:00.000000000', '2019-05-18T00:00:00.000000000',
#        '2019-05-20T00:00:00.000000000', '2019-05-21T00:00:00.000000000',
#        '2019-05-23T00:00:00.000000000', '2019-05-24T00:00:00.000000000',
#        '2019-05-25T00:00:00.000000000', '2019-05-26T00:00:00.000000000',
#        '2019-05-27T00:00:00.000000000', '2019-05-28T00:00:00.000000000',
#        '2019-05-30T00:00:00.000000000', '2019-05-31T00:00:00.000000000',
# ...

# %%
info['rate'].unique()
# Out:
# array([ 70.32 ,  70.39 ,  70.44 ,  70.49 ,  70.43 ,  70.38 ,  70.31 ,
#         70.16 ,  69.96 ,  69.49 ,  69.09 ,  68.8  ,  68.56 ,  68.48 ,
#         68.41 ,  68.5  ,  68.55 ,  68.63 ,  68.76 ,  68.9  ,  69.03 ,
#         69.13 ,  69.21 ,  69.16 ,  69.05 ,  68.94 ,  68.74 ,  68.68 ,
#         68.52 ,  68.4  ,  67.91 ,  67.83 ,  67.67 ,  67.48 ,  67.42 ,
#         67.54 ,  67.61 ,  67.66 ,  67.76 ,  67.85 ,  67.94 ,  68.01 ,
#         70.36 ,  70.4  ,  70.48 ,  70.61 ,  70.67 ,  70.74 ,  70.8  ,
#         70.69 ,  70.64 ,  70.54 ,  70.27 ,  70.21 ,  70.06 ,  69.99 ,
#         69.9  ,  69.76 ,  69.67 ,  69.63 ,  69.4  ,  69.32 ,  69.26 ,
#         69.33 ,  69.48 ,  69.42 ,  69.39 ,  69.31 ,  69.22 ,  69.27 ,
#         69.34 ,  69.41 ,  69.47 ,  69.61 ,  69.85 ,  70.13 ,  70.46 ,
#         71.   ,  71.28 ,  71.49 ,  71.55 ,  71.7  ,  71.77 ,  71.98 ,
#         71.88 ,  71.71 ,  71.43 ,  71.16 ,  70.95 ,  70.83 ,  70.59 ,
# ...

# %%
info['Year'].unique()
# Out:
# array([2019, 2020, 2021, 2022], dtype=int64)

# %%
'''2019 year
.rate
.max rate
.min rate'''
data_19=info[info['Year']==2019]

# %%
data_19
# Out:
#           city       date   rate  Year  Day  Week     Month   dayname
# 0    Ahmedabad 2019-04-22  70.32  2019   22    17     April    Monday
# 1    Ahmedabad 2019-04-22  70.32  2019   22    17     April    Monday
# 2    Ahmedabad 2019-04-22  70.32  2019   22    17     April    Monday
# 3    Ahmedabad 2019-04-22  70.32  2019   22    17     April    Monday
# 4    Ahmedabad 2019-04-22  70.32  2019   22    17     April    Monday
# ..         ...        ...    ...   ...  ...   ...       ...       ...
# 515  Ahmedabad 2019-12-26  72.03  2019   26    52  December  Thursday
# 516  Ahmedabad 2019-12-27  72.09  2019   27    52  December    Friday
# 517  Ahmedabad 2019-12-29  72.22  2019   29    52  December    Sunday
# 518  Ahmedabad 2019-12-30  72.38  2019   30     1  December    Monday
# 519  Ahmedabad 2019-12-31  72.47  2019   31     1  December   Tuesday
#
# [520 rows x 8 columns]

# %%
data_19. min()
# Out:
# city                 Ahmedabad
# date       2019-04-22 00:00:00
# rate                     67.42
# Year                      2019
# Day                          1
# Week                         1
# Month                    April
# dayname                 Friday
# dtype: object

# %%
data_19.max()
# Out:
# city                 Ahmedabad
# date       2019-12-31 00:00:00
# rate                     72.47
# Year                      2019
# Day                         31
# Week                        52
# Month                September
# dayname              Wednesday
# dtype: object

# %%
data_19['rate'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      70.32
# 1      70.32
# 2      70.32
# 3      70.32
# 4      70.32
#        ...
# 515    72.03
# 516    72.09
# 517    72.22
# 518    72.38
# 519    72.47
# Name: rate, Length: 520, dtype: float64>

# %%
data_19['rate'].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0      70.32
# 1      70.32
# 2      70.32
# 3      70.32
# 4      70.32
#        ...
# 515    72.03
# 516    72.09
# 517    72.22
# 518    72.38
# 519    72.47
# Name: rate, Length: 520, dtype: float64>

# %%
data_19['rate'].std()
# Out:
# 0.7078277987228808

# %%
plt.hist(data_19['date'])
# Out:
# (array([387.,  18.,  12.,  14.,  13.,  14.,  17.,  13.,  16.,  16.]),
#  array([18008. , 18033.3, 18058.6, 18083.9, 18109.2, 18134.5, 18159.8,
#         18185.1, 18210.4, 18235.7, 18261. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
#import plotly.express as px
sns.barplot(data=data_19, x='rate',y='Month', alpha=0.7, color='blue')
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Month'>

# %%
data_19.plot(x='rate',y='date')
# Out:
# <AxesSubplot:xlabel='rate'>

# %%
plt.plot(data_19['Month'],data_19['rate'])

# %%
import seaborn as sns
sns.lineplot(data=data_19, x='Year',y='rate')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='rate'>

# %%
data_19.plot(x='date', y='rate')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plt.plot(data_19['Month'],data_19['rate'])

# %%
sns.lineplot(data=info, x='Year', y='rate')
plt.title('distribution of petrol prices year by year')
# Out:
# Text(0.5, 1.0, 'distribution of petrol prices year by year')

# %%
sns.barplot(data=info, x='Year', y= 'rate')
plt.title('comparision between year by year')
# Out:
# Text(0.5, 1.0, 'comparision between year by year')

# %%
#checking _petrol rate in 2020
#.checking the  pertol rate
#checking cloumn by cloumn
data_20=info[info['Year']==2020]
data_20
# Out:
#           city       date   rate  Year  Day  Week     Month   dayname
# 520  Ahmedabad 2020-01-02  72.60  2020    2     1   January  Thursday
# 521  Ahmedabad 2020-01-03  72.69  2020    3     1   January    Friday
# 522  Ahmedabad 2020-01-04  72.79  2020    4     1   January  Saturday
# 523  Ahmedabad 2020-01-05  72.88  2020    5     1   January    Sunday
# 524  Ahmedabad 2020-01-06  73.02  2020    6     2   January    Monday
# ..         ...        ...    ...   ...  ...   ...       ...       ...
# 626  Ahmedabad 2020-12-03  80.04  2020    3    49  December  Thursday
# 627  Ahmedabad 2020-12-04  80.23  2020    4    49  December    Friday
# 628  Ahmedabad 2020-12-05  80.49  2020    5    49  December  Saturday
# 629  Ahmedabad 2020-12-06  80.76  2020    6    49  December    Sunday
# 630  Ahmedabad 2020-12-07  81.05  2020    7    50  December    Monday
#
# [111 rows x 8 columns]

# %%
data_20.plot(x='date',y='rate')
plt.title('distribution  of prices of petrol in year 2020')
# Out:
# Text(0.5, 1.0, 'distribution  of prices of petrol in year 2020')

# %%
sns.lineplot(data=data_20,x='rate', y='Month', alpha=0.85,color='g')
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Month'>

# %%
data_20.min()
# Out:
# city                 Ahmedabad
# date       2020-01-02 00:00:00
# rate                     67.15
# Year                      2020
# Day                          1
# Week                         1
# Month                   August
# dayname                 Friday
# dtype: object

# %%
data_20.max()
# Out:
# city                 Ahmedabad
# date       2020-12-07 00:00:00
# rate                     81.05
# Year                      2020
# Day                         31
# Week                        50
# Month                September
# dayname              Wednesday
# dtype: object

# %%
data_20['rate'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 520    72.60
# 521    72.69
# 522    72.79
# 523    72.88
# 524    73.02
#        ...
# 626    80.04
# 627    80.23
# 628    80.49
# 629    80.76
# 630    81.05
# Name: rate, Length: 111, dtype: float64>

# %%
data_20['Year'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 520    2020
# 521    2020
# 522    2020
# 523    2020
# 524    2020
#        ...
# 626    2020
# 627    2020
# 628    2020
# 629    2020
# 630    2020
# Name: Year, Length: 111, dtype: int64>

# %%
sns.barplot(data=data_20, x='rate',y='Month')
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Month'>

# %% [markdown]
# # 2021
# #. petrol rate
# #.max
# #.min
# #.average

# %%
data_21= info[info['Year']==2021]
data_21
# Out:
#           city       date   rate  Year  Day  Week     Month    dayname
# 631  Ahmedabad 2021-01-05  81.05  2021    5     1   January    Tuesday
# 632  Ahmedabad 2021-01-06  81.32  2021    6     1   January  Wednesday
# 633  Ahmedabad 2021-01-07  81.57  2021    7     1   January   Thursday
# 634  Ahmedabad 2021-01-08  81.57  2021    8     1   January     Friday
# 635  Ahmedabad 2021-01-09  81.57  2021    9     1   January   Saturday
# ..         ...        ...    ...   ...  ...   ...       ...        ...
# 992  Ahmedabad 2021-12-27  95.11  2021   27    52  December     Monday
# 993  Ahmedabad 2021-12-28  95.11  2021   28    52  December    Tuesday
# 994  Ahmedabad 2021-12-29  95.11  2021   29    52  December  Wednesday
# 995  Ahmedabad 2021-12-30  95.11  2021   30    52  December   Thursday
# 996  Ahmedabad 2021-12-31  95.11  2021   31    52  December     Friday
#
# [366 rows x 8 columns]

# %%
import seaborn as sns
sns.lineplot(data=data_21, x='rate',y='Month', alpha=0.8, color= 'blue')
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Month'>

# %%
data_21.min()
# Out:
# city                 Ahmedabad
# date       2021-01-05 00:00:00
# rate                     81.05
# Year                      2021
# Day                          1
# Week                         1
# Month                    April
# dayname                 Friday
# dtype: object

# %%
data_21.max()
# Out:
# city                 Ahmedabad
# date       2021-12-31 00:00:00
# rate                    106.63
# Year                      2021
# Day                         31
# Week                        52
# Month                September
# dayname              Wednesday
# dtype: object

# %%
data_21.mean()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/4024205496.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data_21.mean()
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/4024205496.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_21.mean()
# rate      92.878005
# Year    2021.000000
# Day       16.027322
# Week      25.811475
# dtype: float64

# %%
data_21.median()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/1649673956.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data_21.median()
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/1649673956.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_21.median()
# rate      95.075
# Year    2021.000
# Day       16.000
# Week      25.000
# dtype: float64

# %%
data_21['rate'].mean()
# Out:
# 92.87800546448086

# %%
sns.barplot(data=data_21, x='rate', y='Month')
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Month'>

# %% [markdown]
# # year 2022

# %%
data_22=info[info['Year']== 2022]
data_22
# Out:
#            city       date   rate  Year  Day  Week    Month    dayname
# 997   Ahmedabad 2022-01-01  95.11  2022    1    52  January   Saturday
# 998   Ahmedabad 2022-01-02  95.11  2022    2    52  January     Sunday
# 999   Ahmedabad 2022-01-03  95.11  2022    3     1  January     Monday
# 1000  Ahmedabad 2022-01-04  95.11  2022    4     1  January    Tuesday
# 1001  Ahmedabad 2022-01-05  95.11  2022    5     1  January  Wednesday
# 1002  Ahmedabad 2022-01-06  95.11  2022    6     1  January   Thursday
# 1003  Ahmedabad 2022-01-07  95.11  2022    7     1  January     Friday
# 1004  Ahmedabad 2022-01-08  95.11  2022    8     1  January   Saturday
# 1005  Ahmedabad 2022-01-09  95.11  2022    9     1  January     Sunday
# 1006  Ahmedabad 2022-01-10  95.11  2022   10     2  January     Monday
# 1007  Ahmedabad 2022-01-11  95.11  2022   11     2  January    Tuesday
# 1008  Ahmedabad 2022-01-12  95.11  2022   12     2  January  Wednesday
# ...

# %%
sns.histplot(data=data_22, x='rate', y='Month', alpha=0.69, color= 'black')
plt.title('the analysis of petrol prices in year 2022')
# Out:
# Text(0.5, 1.0, 'the analysis of petrol prices in year 2022')

# %%
sns.barplot(data=data_22, x='rate', y='Month', alpha=0.69, color= 'black')
plt.title('the analysis of petrol prices in year 2022')
# Out:
# Text(0.5, 1.0, 'the analysis of petrol prices in year 2022')

# %%
data_22.max()
# Out:
# city                 Ahmedabad
# date       2022-01-27 00:00:00
# rate                     95.11
# Year                      2022
# Day                         27
# Week                        52
# Month                  January
# dayname              Wednesday
# dtype: object

# %%
data_22.min()
# Out:
# city                 Ahmedabad
# date       2022-01-01 00:00:00
# rate                     95.11
# Year                      2022
# Day                          1
# Week                         1
# Month                  January
# dayname                 Friday
# dtype: object

# %%
data_22.mean()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/946675047.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data_22.mean()
# C:\Users\pc\AppData\Local\Temp/ipykernel_6304/946675047.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_22.mean()
# rate      95.11
# Year    2022.00
# Day       14.00
# Week       6.00
# dtype: float64

# %%
data_22['rate'].mean()
# Out:
# 95.11000000000001
