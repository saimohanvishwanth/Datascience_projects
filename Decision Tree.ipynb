# %%
import numpy as np
import pandas as pd
import sklearn.datasets as datasets
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

#loading iris datasets
iris = pd.read_csv("C:/Users/vishwanth/Downloads/iris_datasets/iris.dataset/iris.csv", header=0)
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# !pip install graphviz
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\vishwanth\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# looking for imbalance datasets
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# defining the varibles
y=iris['sepal.length']
df= iris.copy()
df=df.drop('sepal.length', axis=1)
df.shape
# Out:
# (150, 4)

# %%
#data visulaization
sns.boxplot(data=df, orient='h', palette = 'Set2')
df.corr
# Out:
# <bound method DataFrame.corr of      sepal.width  petal.length  petal.width    variety
# 0            3.5           1.4          0.2     Setosa
# 1            3.0           1.4          0.2     Setosa
# 2            3.2           1.3          0.2     Setosa
# 3            3.1           1.5          0.2     Setosa
# 4            3.6           1.4          0.2     Setosa
# ..           ...           ...          ...        ...
# 145          3.0           5.2          2.3  Virginica
# 146          2.5           5.0          1.9  Virginica
# 147          3.0           5.2          2.0  Virginica
# 148          3.4           5.4          2.3  Virginica
# 149          3.0           5.1          1.8  Virginica
#
# [150 rows x 4 columns]>

# %%
#pair plot to visualize
sns.pairplot(iris,hue ='sepal.width')

# %%
#decision tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test = train_test_split(df, y, test_size=0.25 , random_state = 40)
print(x_train.shape, x_test.shape, y_train.shape,y_test.shape)
# Out:
# (112, 4) (38, 4) (112,) (38,)

# %%
# Defining the Decision Tree
from sklearn.tree import DecisionTreeClassifier
d = DecisionTreeClassifier()
d.fit(x_train,y_train)
print('decision tree classifier created')
dtree
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 4>()
#       2 from sklearn.tree import DecisionTreeClassifier
#       3 d = DecisionTreeClassifier()
# ----> 4 d.fit(x_train,y_train)
#       5 print('decision tree classifier created')
#       6 dtree
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
# ...

# %%
#predicting the datasets
predictions = dtree.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 #predicting the datasets
# ----> 2 predictions = dtree.predict(x_test)
#
# NameError: name 'dtree' is not defined

# %%
# constructing the confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
print('confusion matrix', confusion_matrix(y_test,predictions))

# %%
#importing the neccesary libraries for grapgh viz
import graphviz
from sklearn.tree import DecisionTreeClassifer
from sklearn  import tree

# %%
#visualizing the tree
coulmns =list(df.columns)
dot_data =tree.export_graphviz(dtree, out_file=None, features_name= columns, class_name= True)
graph = graphviz.Source(dot_data)
graph.render(view =  True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 #visualizing the tree
#       2 coulmns =list(df.columns)
# ----> 3 dot_data =tree.export_graphviz(dtree, out_file=None, features_name= columns, class_name= True)
#       4 graph = graphviz.Source(dot_data)
#       5 graph.render(view =  True)
#
# NameError: name 'tree' is not defined
